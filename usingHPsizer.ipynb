# %%
from HPsizer import HPsizer

# %%
hps = HPsizer('Cell 1A_1B Chilled Water Load -data-2022-09-30 00_41_29.csv', charge_p=(20,8), discharge_p=(12,19)) # specify date range?
hps.sizing_plot()

# %%
hps.sizing_plot()

# %%
hps = HPsizer('Cell 1A_1B Chilled Water Load -data-2022-09-30 00_41_29.csv', charge_p=(20,10), discharge_p=(12,20), day = '2021-10-10') # specify date range?
hps.sizing_plot()

# %%
hps = HPsizer('Cell 1A_1B Chilled Water Load -data-2022-09-30 00_41_29.csv', charge_p=(20,8), discharge_p=(11,19), method = 'highest_7_days') # specify date range?
hps.sizing_plot()
# Out:
# df represents days Index([2021-10-05, 2021-10-03, 2021-10-01, 2021-09-14, 2021-10-02, 2021-10-04,
#        2021-09-21],
#       dtype='object')

# %%
dre_example = HPsizer('MFRSizing.csv', 
        charge_p=(10,15), discharge_p=(17,20), 
        day = '2020-1-29', 
        index_col = 'Time', value_col = 'QHea')
dre_example.sizing_plot()
