# %%
from HPsizer import HPsizer

# %%
hps = HPsizer('OneDaynoUnits.csv', ('21:00','15:00'), discharge_p=('17:00','20:00'))
hps.sizing_plot()
# Out:
# /Users/lazlopaul/Desktop/Misc/HP_TES_sizing/HPsizer.py:193: UserWarning: no units supplied, assuming W
#   warn('no units supplied, assuming W')

# %%
hps = HPsizer('Cell 1A_1B Chilled Water Load -data-2022-09-30 00_41_29.csv', charge_p=('20:00','8:00'), discharge_p=('12:00','19:00')) # specify date range?
hps.sizing_plot()

# %%
hps = HPsizer('Cell 1A_1B Chilled Water Load -data-2022-09-30 00_41_29.csv', charge_p=('20:00','8:00'), discharge_p=('11:00','19:00'), method = 'highest_7_days')
hps.sizing_plot()
# Out:
# df represents days Index([2021-10-05, 2021-10-03, 2021-10-01, 2021-09-14, 2021-10-02, 2021-10-04,
#        2021-09-21],
#       dtype='object')

# %%
dre_example = HPsizer('MFRSizing.csv', 
        charge_p=('10:00','15:00'), discharge_p=('17:00','20:00'), 
        day = '2020-1-29', 
        index_col = 'Time', value_col = 'QHea')
dre_example.sizing_plot()
